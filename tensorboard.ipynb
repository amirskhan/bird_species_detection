# %% [markdown]
# # Tensorboard

# %% [markdown]
# ## Faster R-CNN

# %%
PATH_TO_MODEL = "faster_rcnn_resnet101_v1_1024x1024_coco17_tpu-8"

# %%
# !tensorboard --logdir=training/{PATH_TO_MODEL}/
# Out:
# 2022-01-10 16:12:07.838737: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.6.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %% [markdown]
# ### Training Loss

# %%
from IPython.display import Image
Image(filename='rcnn_loss.png')

# %%
Image(filename='rcnn_loss2.png')

# %%
Image(filename='rcnn_lr.png')

# %% [markdown]
# As you can see the losses are not mving after 20k steps. That is why I did not do more training.

# %% [markdown]
# ## SSD ResNet50

# %%
PATH_TO_MODEL = "ssd_resnet50_v1_fpn_640x640_coco17_tpu-8"

# %%
# !tensorboard --logdir=training/{PATH_TO_MODEL}/
# Out:
# 2022-01-10 16:13:49.643641: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.6.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %% [markdown]
# ### Training Loss

# %%
Image(filename='ssd_loss.png')

# %%
Image(filename='ssd_lr.png')

# %% [markdown]
# Even for SSD the loss wasn't moving down after 20k steps. So I did not train the model more.
